# %%
# !nvidia-smi

# %%
from google.colab import drive

drive.mount('/content/drive', force_remount=True)
COLAB = True
print("Note: using Google CoLab")

# %%
# !pip install pytorch-lightning

# %%
# !pip install wandb

# %%
# !pip install albumentations==0.4.6

# %%
# !python -m pip install -U scikit-image

# %%
# !pip install efficientnet_pytorch

# %%
import wandb
wandb.login()

# %% [markdown]
# ## 2. FDA, 2.1. Source: CVC-EndoScene → Target: ETIS Larib, Experiment 1:

# %%
import os

MODEL_TYPE = "EfficientNet"
RUN_NAME = "RUN_1"
PROJECT_NAME = "CoVision-Classification"

CHECKPOINT_DIR_BASE = "/content/drive/MyDrive/CoVision/Github/CoVision/classification_model_training/experiments"
CHECKPOINT_DIR = os.path.join(CHECKPOINT_DIR_BASE, PROJECT_NAME, RUN_NAME)

TRAIN_DATA_PATH = "/content/drive/MyDrive/CoVision/Github/CoVision/classification_model_training/data/train"
TEST_DATA_PATH = "/content/drive/MyDrive/CoVision/Github/CoVision/classification_model_training/data/test"
LOAD_SIZE = 256
MAX_EPOCHS = 500

TRAIN_PATH = "/content/drive/MyDrive/CoVision/Github/CoVision/classification_model_training/lightning_ai/trainer.py"

cmd = f"/usr/bin/python3 {TRAIN_PATH} --checkpoint_dir {CHECKPOINT_DIR} --run_name {RUN_NAME} --project_name {PROJECT_NAME} --train_data_path {TRAIN_DATA_PATH} --test_data_path {TEST_DATA_PATH} --load_size {LOAD_SIZE} --max_epochs {MAX_EPOCHS}"
# !{cmd}
# Out:
# Loaded pretrained weights for efficientnet-b2
# wandb: Currently logged in as: lennart-maack. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.3
# wandb: Run data is saved locally in ./wandb/run-20220921_143711-17y80jvj
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run RUN_1
# wandb: ⭐️ View project at https://wandb.ai/lennart-maack/CoVision-Classification
# wandb: 🚀 View run at https://wandb.ai/lennart-maack/CoVision-Classification/runs/17y80jvj
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name          | Type             | Params
# ---------------------------------------------------
# 0 | net           | EfficientNet     | 7.7 M
# 1 | loss_function | CrossEntropyLoss | 0
# ---------------------------------------------------
# 7.7 M     Trainable params
# 0         Non-trainable params
# 7.7 M     Total params
# 30.827    Total estimated model params size (MB)
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1896: PossibleUserWarning: The number of training batches (18) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Epoch 0:   0% 0/23 [00:00<?, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 0:  87% 20/23 [00:36<00:05,  1.85s/it]
# Epoch 0: 100% 23/23 [00:37<00:00,  1.61s/it, loss=1.32, v_num=0jvj, Train - CrossEntropyLoss=1.100, Val - CrossEntropyLoss=1.360]
# Epoch 1:   0% 0/23 [00:00<?, ?it/s, loss=1.32, v_num=0jvj, Train - CrossEntropyLoss=1.100, Val - CrossEntropyLoss=1.360]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 1:  87% 20/23 [00:04<00:00,  4.32it/s, loss=1.32, v_num=0jvj, Train - CrossEntropyLoss=1.100, Val - CrossEntropyLoss=1.360]
# Epoch 1: 100% 23/23 [00:04<00:00,  4.80it/s, loss=0.776, v_num=0jvj, Train - CrossEntropyLoss=0.470, Val - CrossEntropyLoss=1.510]
# Epoch 2:   0% 0/23 [00:00<?, ?it/s, loss=0.776, v_num=0jvj, Train - CrossEntropyLoss=0.470, Val - CrossEntropyLoss=1.510]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 2:  87% 20/23 [00:04<00:00,  4.24it/s, loss=0.776, v_num=0jvj, Train - CrossEntropyLoss=0.470, Val - CrossEntropyLoss=1.510]
# Epoch 2: 100% 23/23 [00:04<00:00,  4.69it/s, loss=0.479, v_num=0jvj, Train - CrossEntropyLoss=0.492, Val - CrossEntropyLoss=1.120]
# Epoch 3:   0% 0/23 [00:00<?, ?it/s, loss=0.479, v_num=0jvj, Train - CrossEntropyLoss=0.492, Val - CrossEntropyLoss=1.120]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 3:  87% 20/23 [00:04<00:00,  4.27it/s, loss=0.479, v_num=0jvj, Train - CrossEntropyLoss=0.492, Val - CrossEntropyLoss=1.120]
# Epoch 3: 100% 23/23 [00:04<00:00,  4.73it/s, loss=0.452, v_num=0jvj, Train - CrossEntropyLoss=0.530, Val - CrossEntropyLoss=2.230]
# Epoch 4:   0% 0/23 [00:00<?, ?it/s, loss=0.452, v_num=0jvj, Train - CrossEntropyLoss=0.530, Val - CrossEntropyLoss=2.230]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 4:  87% 20/23 [00:04<00:00,  4.14it/s, loss=0.452, v_num=0jvj, Train - CrossEntropyLoss=0.530, Val - CrossEntropyLoss=2.230]
# Epoch 4: 100% 23/23 [00:04<00:00,  4.60it/s, loss=0.341, v_num=0jvj, Train - CrossEntropyLoss=0.174, Val - CrossEntropyLoss=2.020]
# Epoch 5:   0% 0/23 [00:00<?, ?it/s, loss=0.341, v_num=0jvj, Train - CrossEntropyLoss=0.174, Val - CrossEntropyLoss=2.020]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 5:  87% 20/23 [00:04<00:00,  4.02it/s, loss=0.341, v_num=0jvj, Train - CrossEntropyLoss=0.174, Val - CrossEntropyLoss=2.020]
# Epoch 5: 100% 23/23 [00:05<00:00,  4.47it/s, loss=0.138, v_num=0jvj, Train - CrossEntropyLoss=0.0857, Val - CrossEntropyLoss=1.530]
# Epoch 6:   0% 0/23 [00:00<?, ?it/s, loss=0.138, v_num=0jvj, Train - CrossEntropyLoss=0.0857, Val - CrossEntropyLoss=1.530]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 6:  87% 20/23 [00:04<00:00,  4.27it/s, loss=0.138, v_num=0jvj, Train - CrossEntropyLoss=0.0857, Val - CrossEntropyLoss=1.530]
# Epoch 6: 100% 23/23 [00:04<00:00,  4.73it/s, loss=0.0832, v_num=0jvj, Train - CrossEntropyLoss=0.0205, Val - CrossEntropyLoss=3.320]
# Epoch 7:   0% 0/23 [00:00<?, ?it/s, loss=0.0832, v_num=0jvj, Train - CrossEntropyLoss=0.0205, Val - CrossEntropyLoss=3.320]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 7:  87% 20/23 [00:04<00:00,  4.27it/s, loss=0.0832, v_num=0jvj, Train - CrossEntropyLoss=0.0205, Val - CrossEntropyLoss=3.320]
# Epoch 7: 100% 23/23 [00:04<00:00,  4.74it/s, loss=0.0616, v_num=0jvj, Train - CrossEntropyLoss=0.0435, Val - CrossEntropyLoss=2.770]
# Epoch 8:   0% 0/23 [00:00<?, ?it/s, loss=0.0616, v_num=0jvj, Train - CrossEntropyLoss=0.0435, Val - CrossEntropyLoss=2.770]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 8:  87% 20/23 [00:04<00:00,  4.22it/s, loss=0.0616, v_num=0jvj, Train - CrossEntropyLoss=0.0435, Val - CrossEntropyLoss=2.770]
# Epoch 8: 100% 23/23 [00:04<00:00,  4.69it/s, loss=0.169, v_num=0jvj, Train - CrossEntropyLoss=0.264, Val - CrossEntropyLoss=3.570]
# Epoch 9:   0% 0/23 [00:00<?, ?it/s, loss=0.169, v_num=0jvj, Train - CrossEntropyLoss=0.264, Val - CrossEntropyLoss=3.570]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 9:  87% 20/23 [00:04<00:00,  4.17it/s, loss=0.169, v_num=0jvj, Train - CrossEntropyLoss=0.264, Val - CrossEntropyLoss=3.570]
# Epoch 9: 100% 23/23 [00:04<00:00,  4.63it/s, loss=0.212, v_num=0jvj, Train - CrossEntropyLoss=0.080, Val - CrossEntropyLoss=2.980]
# Epoch 10:   0% 0/23 [00:00<?, ?it/s, loss=0.212, v_num=0jvj, Train - CrossEntropyLoss=0.080, Val - CrossEntropyLoss=2.980]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 10:  87% 20/23 [00:04<00:00,  4.28it/s, loss=0.212, v_num=0jvj, Train - CrossEntropyLoss=0.080, Val - CrossEntropyLoss=2.980]
# Epoch 10: 100% 23/23 [00:04<00:00,  4.77it/s, loss=0.115, v_num=0jvj, Train - CrossEntropyLoss=0.0803, Val - CrossEntropyLoss=3.180]
# Epoch 11:   0% 0/23 [00:00<?, ?it/s, loss=0.115, v_num=0jvj, Train - CrossEntropyLoss=0.0803, Val - CrossEntropyLoss=3.180]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 11:  87% 20/23 [00:05<00:00,  3.96it/s, loss=0.115, v_num=0jvj, Train - CrossEntropyLoss=0.0803, Val - CrossEntropyLoss=3.180]
# Epoch 11: 100% 23/23 [00:05<00:00,  4.42it/s, loss=0.147, v_num=0jvj, Train - CrossEntropyLoss=0.00605, Val - CrossEntropyLoss=4.950]
# Epoch 12:   0% 0/23 [00:00<?, ?it/s, loss=0.147, v_num=0jvj, Train - CrossEntropyLoss=0.00605, Val - CrossEntropyLoss=4.950]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 12:  87% 20/23 [00:04<00:00,  4.29it/s, loss=0.147, v_num=0jvj, Train - CrossEntropyLoss=0.00605, Val - CrossEntropyLoss=4.950]
# Epoch 12: 100% 23/23 [00:04<00:00,  4.74it/s, loss=0.208, v_num=0jvj, Train - CrossEntropyLoss=0.258, Val - CrossEntropyLoss=5.060]
# Epoch 13:   0% 0/23 [00:00<?, ?it/s, loss=0.208, v_num=0jvj, Train - CrossEntropyLoss=0.258, Val - CrossEntropyLoss=5.060]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 13:  87% 20/23 [00:04<00:00,  4.20it/s, loss=0.208, v_num=0jvj, Train - CrossEntropyLoss=0.258, Val - CrossEntropyLoss=5.060]
# Epoch 13: 100% 23/23 [00:04<00:00,  4.67it/s, loss=0.232, v_num=0jvj, Train - CrossEntropyLoss=0.313, Val - CrossEntropyLoss=1.390]
# Epoch 14:   0% 0/23 [00:00<?, ?it/s, loss=0.232, v_num=0jvj, Train - CrossEntropyLoss=0.313, Val - CrossEntropyLoss=1.390]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 14:  87% 20/23 [00:04<00:00,  4.22it/s, loss=0.232, v_num=0jvj, Train - CrossEntropyLoss=0.313, Val - CrossEntropyLoss=1.390]
# Epoch 14: 100% 23/23 [00:04<00:00,  4.69it/s, loss=0.288, v_num=0jvj, Train - CrossEntropyLoss=0.821, Val - CrossEntropyLoss=2.200]
# Epoch 15:   0% 0/23 [00:00<?, ?it/s, loss=0.288, v_num=0jvj, Train - CrossEntropyLoss=0.821, Val - CrossEntropyLoss=2.200]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 15:  87% 20/23 [00:04<00:00,  4.25it/s, loss=0.288, v_num=0jvj, Train - CrossEntropyLoss=0.821, Val - CrossEntropyLoss=2.200]
# Epoch 15: 100% 23/23 [00:04<00:00,  4.72it/s, loss=0.22, v_num=0jvj, Train - CrossEntropyLoss=0.688, Val - CrossEntropyLoss=2.190]
# Epoch 16:   0% 0/23 [00:00<?, ?it/s, loss=0.22, v_num=0jvj, Train - CrossEntropyLoss=0.688, Val - CrossEntropyLoss=2.190]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 16:  87% 20/23 [00:04<00:00,  4.03it/s, loss=0.22, v_num=0jvj, Train - CrossEntropyLoss=0.688, Val - CrossEntropyLoss=2.190]
# Epoch 16: 100% 23/23 [00:05<00:00,  4.48it/s, loss=0.176, v_num=0jvj, Train - CrossEntropyLoss=0.0163, Val - CrossEntropyLoss=1.080]
# Epoch 17:   0% 0/23 [00:00<?, ?it/s, loss=0.176, v_num=0jvj, Train - CrossEntropyLoss=0.0163, Val - CrossEntropyLoss=1.080]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 17:  87% 20/23 [00:04<00:00,  4.24it/s, loss=0.176, v_num=0jvj, Train - CrossEntropyLoss=0.0163, Val - CrossEntropyLoss=1.080]
# Epoch 17: 100% 23/23 [00:04<00:00,  4.69it/s, loss=0.119, v_num=0jvj, Train - CrossEntropyLoss=0.0172, Val - CrossEntropyLoss=1.770]
# Epoch 18:   0% 0/23 [00:00<?, ?it/s, loss=0.119, v_num=0jvj, Train - CrossEntropyLoss=0.0172, Val - CrossEntropyLoss=1.770]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 18:  87% 20/23 [00:04<00:00,  4.16it/s, loss=0.119, v_num=0jvj, Train - CrossEntropyLoss=0.0172, Val - CrossEntropyLoss=1.770]
# Epoch 18: 100% 23/23 [00:04<00:00,  4.62it/s, loss=0.0494, v_num=0jvj, Train - CrossEntropyLoss=0.00468, Val - CrossEntropyLoss=1.900]
# Epoch 19:   0% 0/23 [00:00<?, ?it/s, loss=0.0494, v_num=0jvj, Train - CrossEntropyLoss=0.00468, Val - CrossEntropyLoss=1.900]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 19:  87% 20/23 [00:04<00:00,  4.06it/s, loss=0.0494, v_num=0jvj, Train - CrossEntropyLoss=0.00468, Val - CrossEntropyLoss=1.900]
# Epoch 19: 100% 23/23 [00:05<00:00,  4.50it/s, loss=0.0459, v_num=0jvj, Train - CrossEntropyLoss=0.00915, Val - CrossEntropyLoss=1.520]
# Epoch 20:   0% 0/23 [00:00<?, ?it/s, loss=0.0459, v_num=0jvj, Train - CrossEntropyLoss=0.00915, Val - CrossEntropyLoss=1.520]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 20:  87% 20/23 [00:04<00:00,  4.10it/s, loss=0.0459, v_num=0jvj, Train - CrossEntropyLoss=0.00915, Val - CrossEntropyLoss=1.520]
# Epoch 20: 100% 23/23 [00:05<00:00,  4.57it/s, loss=0.0964, v_num=0jvj, Train - CrossEntropyLoss=0.0113, Val - CrossEntropyLoss=1.570]
# Epoch 21:   0% 0/23 [00:00<?, ?it/s, loss=0.0964, v_num=0jvj, Train - CrossEntropyLoss=0.0113, Val - CrossEntropyLoss=1.570]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 21:  87% 20/23 [00:04<00:00,  4.16it/s, loss=0.0964, v_num=0jvj, Train - CrossEntropyLoss=0.0113, Val - CrossEntropyLoss=1.570]
# Epoch 21: 100% 23/23 [00:04<00:00,  4.62it/s, loss=0.0702, v_num=0jvj, Train - CrossEntropyLoss=0.00528, Val - CrossEntropyLoss=0.811]
# Epoch 22:   0% 0/23 [00:00<?, ?it/s, loss=0.0702, v_num=0jvj, Train - CrossEntropyLoss=0.00528, Val - CrossEntropyLoss=0.811]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 22:  87% 20/23 [00:05<00:00,  3.97it/s, loss=0.0702, v_num=0jvj, Train - CrossEntropyLoss=0.00528, Val - CrossEntropyLoss=0.811]
# Epoch 22: 100% 23/23 [00:05<00:00,  4.42it/s, loss=0.12, v_num=0jvj, Train - CrossEntropyLoss=0.101, Val - CrossEntropyLoss=0.852]
# Epoch 23:   0% 0/23 [00:00<?, ?it/s, loss=0.12, v_num=0jvj, Train - CrossEntropyLoss=0.101, Val - CrossEntropyLoss=0.852]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 23:  87% 20/23 [00:04<00:00,  4.12it/s, loss=0.12, v_num=0jvj, Train - CrossEntropyLoss=0.101, Val - CrossEntropyLoss=0.852]
# Epoch 23: 100% 23/23 [00:05<00:00,  4.51it/s, loss=0.0567, v_num=0jvj, Train - CrossEntropyLoss=0.00315, Val - CrossEntropyLoss=1.260]
# Epoch 24:   0% 0/23 [00:00<?, ?it/s, loss=0.0567, v_num=0jvj, Train - CrossEntropyLoss=0.00315, Val - CrossEntropyLoss=1.260]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 24:  87% 20/23 [00:04<00:00,  4.02it/s, loss=0.0567, v_num=0jvj, Train - CrossEntropyLoss=0.00315, Val - CrossEntropyLoss=1.260]
# Epoch 24: 100% 23/23 [00:05<00:00,  4.46it/s, loss=0.0659, v_num=0jvj, Train - CrossEntropyLoss=0.0775, Val - CrossEntropyLoss=2.790]
# Epoch 25:   0% 0/23 [00:00<?, ?it/s, loss=0.0659, v_num=0jvj, Train - CrossEntropyLoss=0.0775, Val - CrossEntropyLoss=2.790]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/5 [00:00<?, ?it/s]
# Epoch 25:  87% 20/23 [00:04<00:00,  4.10it/s, loss=0.0659, v_num=0jvj, Train - CrossEntropyLoss=0.0775, Val - CrossEntropyLoss=2.790]
# Epoch 25: 100% 23/23 [00:05<00:00,  4.57it/s, loss=0.0381, v_num=0jvj, Train - CrossEntropyLoss=0.130, Val - CrossEntropyLoss=2.220]
# Epoch 26:   0% 0/23 [00:00<?, ?it/s, loss=0.0381, v_num=0jvj, Train - CrossEntropyLoss=0.130, Val - CrossEntropyLoss=2.220]
