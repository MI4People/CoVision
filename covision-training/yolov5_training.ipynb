# %% [markdown]
# ## check with GPU you have access to --> need to set GPU as accelerator under Notebook properties

# %%
# !nvidia-smi
# Out:
# Wed Apr 20 14:11:54 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8    28W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## mount your drive folder to the colab

# %%
from google.colab import drive
 
drive.mount('/content/drive', force_remount=True)
COLAB = True
print("Note: using Google CoLab")
# Out:
# Mounted at /content/drive
# Note: using Google CoLab

# %%
# %cd drive/MyDrive/Makeathon_TUM/yolov5
# Out:
# /content/drive/MyDrive/Makeathon_TUM/yolov5

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/Makeathon_TUM

# %% [markdown]
# ## Install dependencies

# %%
# !pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio===0.8.1 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html

# %%
# !pip install -r requirements.txt

# %%
# %ls
# Out:
#  CoVision/            labelImg/          rapid_test_IMG_2536.txt
#  data/                orga/              yolov5/
#  helper_funcs.ipynb  'Pitch Deck.gdoc'   yolov5_training.ipynb

# %% [markdown]
# ## Export model to tfjs format

# %%
# !python ./yolov5/export.py --weights ./CoVision/yolov5s_rapid_test.pt --include tfjs
# Out:
# ...
# export: data=yolov5/data/coco128.yaml, weights=['./CoVision/yolov5s_rapid_test.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, train=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tfjs']
# YOLOv5 🚀 v6.1-135-g7926afc torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
#
# PyTorch: starting from CoVision/yolov5s_rapid_test.pt with output shape (1, 25200, 6) (13.8 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.8.0...
#
#                  from  n    params  module                                  arguments
# 2022-04-20 14:14:23.187523: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %% [markdown]
# # Train the model

# %%
# !pip install wandb

# %%
# !python train.py --img 640 --batch 16 --epochs 200 --data dataset.yaml --weights yolov5s.pt --workers 2
